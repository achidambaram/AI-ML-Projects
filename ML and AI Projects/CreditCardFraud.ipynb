# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
dataset = pd.read_csv('/content/creditcard 2.csv')
dataset.head()

dataArr = dataset.to_numpy()

fraud_cases = dataset['Class']
fraud_cases = np.array(fraud_cases)

def fraud_case_count(fraud_arr):
  fraud_counter = 0
  no_fraud_counter = 0

  for i in range(len(fraud_arr)):
    if fraud_cases[i] == 1:
      fraud_counter += 1
    else:
      no_fraud_counter += 1

  return fraud_counter, no_fraud_counter

fraud_count, no_fraud_count = fraud_case_count(fraud_cases)

print(fraud_count)

print(no_fraud_count)

dataset.head()

x = dataset.iloc[:, :30]
x.head()

y = dataset.iloc[:, 30:]
y.head()

scaler = StandardScaler()

scaler.fit(x)

data = scaler.transform(x)
# Out:
# 492
# 284315
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-aef6d4114787> in <module>()
#      39 data = scaler.transform(x)
#      40
# ---> 41 data.head()
#      42
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'
