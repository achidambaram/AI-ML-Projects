# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv("/content/cars.csv", ";", skiprows = [1])
print(dataset)
dataset.head()
x = dataset[['MPG','Acceleration']]
y = dataset[['Horsepower']]

x1 = dataset[['MPG']]
x2 = dataset[['Acceleration']]
y = dataset[['Horsepower']]

plt.plot(dataset['MPG'], y, 'bo')
plt.xlabel('MPG')
plt.ylabel('Horsepower')

plt.figure()

plt.plot(dataset['Acceleration'], y, 'go')
plt.xlabel('Acceleration')
plt.ylabel('Horsepower')



dataset.head()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

#model = LinearRegression()

#model.fit(x_train, y_train)

#model.score(x_test, y_test)

xMatrix = x_train.values
yMatrix = y_train.values


print(len(xMatrix))
#print(xsubMatrix)


#print((xMatrix))
###print((oneMatrix))
#print(len(xMatrix))
#print(len(xMatrix[0]))
#print(len(oneMatrix))


#print(len(oneMatrix[0]))
oneMatrix = np.ones((len(xMatrix), 1))

#print(len(xMatrix[0]))
##print(xMatrix)
A = np.concatenate((oneMatrix, xMatrix), axis=1)
print(A)

## uncomment after testingg print(A)

yrMatrix = np.repeat(yMatrix, 2)
#print(len(yrMatrix))

Fmatrix = np.linalg.lstsq(A, yMatrix)[0]
print(Fmatrix)
# print(Fmatrix[0])

# def predict(x1, x2):
#   y = x1.values * Fmatrix[1] + x2.values * Fmatrix[2] + Fmatrix[0]
#   print(y)

# # y = x1.values * Fmatrix[1] + x2.values * Fmatrix[2] + Fmatrix[0]
# print(predict(x1, x2))

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter3D(x1, x2, y)
# Out:
#                            Car   MPG  Cylinders  ...  Acceleration  Model  Origin
# 0    Chevrolet Chevelle Malibu  18.0          8  ...          12.0     70      US
# 1            Buick Skylark 320  15.0          8  ...          11.5     70      US
# 2           Plymouth Satellite  18.0          8  ...          11.0     70      US
# 3                AMC Rebel SST  16.0          8  ...          12.0     70      US
# 4                  Ford Torino  17.0          8  ...          10.5     70      US
# ..                         ...   ...        ...  ...           ...    ...     ...
# 401            Ford Mustang GL  27.0          4  ...          15.6     82      US
# 402          Volkswagen Pickup  44.0          4  ...          24.6     82  Europe
# 403              Dodge Rampage  32.0          4  ...          11.6     82      US
# 404                Ford Ranger  28.0          4  ...          18.6     82      US
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %%
print(X)
