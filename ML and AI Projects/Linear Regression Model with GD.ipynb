# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import math
import sympy as sym
import statistics

# %%
# from re import M
dataset = pd.read_csv("/content/housing.csv")
dataset.head()

x = dataset['median_income']
y = dataset['median_house_value']

yAr = []

xArray = x.to_numpy()
yArray = y.to_numpy()

print(np.shape(xArray))
print(np.shape(yArray))


# print()

# newX = []
# newY = []

# for x in range(100):
#   xStat = (xArray[x] - statistics.mean(xArray)) / len(xArray)
#   newX.append(xStat)

# for y in range(100):
#   yStat = (yArray[y] - statistics.mean(yArray)) / len(yArray)
#   newY.append(yStat)


# nAx = np.array(newX)
# nAy = np.array(newY)

# xT = xArray.transpose()

# print(xT)
# print(yArray)

def gradient_descent(x,y):
    global m_curr
    global b_curr
    m_curr = 0
    b_curr = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.05

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd

        
        print ("m {}, b {}, cost {}, md {}, bd {}, iteration {}".format(m_curr, b_curr, md, bd, cost, i))
    
    plt.plot(x, m_curr * x + b_curr)
    
gradient_descent(xArray, yArray)

plt.scatter(xArray, yArray, color='green')

def predictHouseValue(x):
    y_pred = []

    for i in range(1000):
      y_pred = m_curr * x + b_curr

    print(y_pred)

predictHouseValue(3.12)
# Out:
# (20640,)
# (20640,)
# m 95151.09865825529, b 20685.58169089147, cost -1903021.9731651056, md -413711.6338178294, bd 56104831989.87253, iteration 0
# m 5397.78185273477, b 2472.7453655687714, cost 1795066.3361104103, md 364256.726506454, bd 50457281491.21587, iteration 1
# m 89556.61542445754, b 20821.748750163457, cost -1683176.6714344553, md -366980.06769189367, bd 45460847114.388504, iteration 2
# m 10151.431830129033, b 4760.7361218447, cost 1588103.67188657, md 321220.25256637513, bd 41040407240.022385, iteration 3
# m 84587.03388447323, b 21040.95891826492, cost -1488712.041086884, md -325604.4559284044, bd 37129509267.11018, iteration 4
# m 14336.07040300843, b 6881.586789475936, cost 1405019.269629296, md 283187.4425757797, bd 33669369137.71906, iteration 5
# m 80170.99822470693, b 21329.98860096407, cost -1316698.5564339699, md -288968.03622976266, bd 30607986327.383987, iteration 6
# ...
